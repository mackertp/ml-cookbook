// %% [markdown]
// # Java Books
//
// Java is a widely used language for creating applications and systems. Some of it's core features include a simple syntax, object orientation, and a robust, secure ecosystem that is capable of running on any platform. To get a little more familiar with the language, look at [javatpoint](https://www.javatpoint.com/java-basics#:~:text=Simple%3A%20Java%20is%20a%20simple,the%20form%20of%20the%20object.) for some excellent free resources.
//
// Thanks to [Spencer Park](https://github.com/SpencerPark/IJava), we are able to add a Java kernel to our Jupyter workspace. This notebook is just a demonstration of using that Kernel. You can read the notes provided on Spencer's repo to ensure your install works if you want to follow along.

// %%
System.out.println("Hello, World");
// Out:
// Hello, World

// %%
import java.util.Scanner;

// %%
public class Factorial {  
    static int factorial(int n){      
          if (n == 1)      
            return 1;      
          else      
            return(n * factorial(n-1));      
    }      
  
    public void findFactorial() {
        /* 
         * read a number from the user and display it's factorial
         */
        Scanner scan = new Scanner(System.in);
        System.out.print("Enter a number: ");
        int num = scan.nextInt();
        scan.close();
        
        // find the factorial
        String return_string = String.format("The factorial of %d is: ", num); 
        System.out.println(return_string + factorial(num));  
    }  
}

// %%
Factorial myfac = new Factorial();
myfac.findFactorial();
// Out:
// Enter a number:
//  4
// The factorial of 4 is: 24

// %% [markdown]
// ## Frameworks
//
// When working with a language, it is generally a good idea to select a framework to help you complete your project. In Java, I find that [JavaFx](https://openjfx.io/) is the easiest to use and has the best looking components to work with.
